# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob 
import errno 
import itertools
plt.figure(figsize=(20,11))
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/LPP_Caff_5000eq_0.2/Force_prod/Convergence/Single')
with open('data.txt', 'w') as file:
    
    path = './*pullx.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('result_*')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name)
       
            X=f[:,1]
            Y=f[:,2]
            
            plt.subplot(2, 3, 1)
            plt.plot(X,Y,':ro',label=name,color=next(colors))

            plt.ylabel('Force (kJ/mol/nm)',fontsize=14)
            plt.xlabel('Time (ns)',fontsize=14)
            plt.ylim(-50, 60)
            plt.xlim(0, 200)
            #plt.legend(loc='best')
            plt.minorticks_on()

            
            #plt.figure(2)
            #plt.hist(Y, bins = 40, label=r'$\Delta$x,y')
            #plt.ylabel('Frequency',fontsize=14)
            #plt.xlabel('$\Delta$z (nm) ',fontsize=14)
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise     
#plt.subplots_adjust(bottom=0.05, right=0.8, top=0.9)
plt.subplots_adjust(hspace=0.4)

plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/Convergence.png',dpi=300,bbox_inches='tight',pad_inches=0.20)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob 
import errno 
import itertools
plt.figure(figsize=(20,11))
 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_Symm/Caff_Sym_0.2/All')
with open('data.txt', 'w') as file:
    
    path = './*pullx.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*pullx.xvg')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name)
       
            X=f[:,0]
            Y=f[:,1]
            
            plt.subplot(2, 3, 1)
            plt.plot(X,Y,':ro',label=name,color=next(colors))

            plt.ylabel('Z coordinate (nm)',fontsize=14)
            plt.xlabel('Time (ns)',fontsize=14)
            plt.ylim(-100, 100)
            plt.xlim(0, 100)
            #plt.legend(loc='best')
            
            plt.title('SPP: Caff Pulling experiments')
            #plt.figure(2)
            #plt.hist(Y, bins = 40, label=r'$\Delta$x,y')
            #plt.ylabel('Frequency',fontsize=14)
            #plt.xlabel('$\Delta$z (nm) ',fontsize=14)
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise      

#plt.subplots_adjust(bottom=0.05, right=0.8, top=0.9)
plt.subplots_adjust(hspace=0.4)

#plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_3wat/SPP_PMF_.png',dpi=300,bbox_inches='tight',pad_inches=0.20)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob 
import errno 
import itertools
plt.figure(figsize=(20,11))

 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/PMF/PMF_DPG_Lor')
with open('data.txt', 'w') as file:
    
    path = './fes_all.dat' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["blue", "blue", "r","r","c","m"])
    markers = itertools.cycle(["o","x","o","x"])

for name in sorted(glob.glob('fes_*')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name)
       
            X=f[:,0]
            Y=f[:,1]*(-1)
            Z=f[:,2]
            
            plt.subplot(2, 3, 1)
            plt.plot(X,Y,':ro',label=name,color=next(colors),marker=next(markers))
            #plt.errorbar(X,Y, yerr=Z, label='both limits (default)')


            plt.ylabel('PMF (kJ/mol)',fontsize=14)
            plt.xlabel('Z direction (nm)',fontsize=14)
            plt.ylim(0, 50)
            plt.xlim(-5, 6)
            plt.legend(loc='center top')
            plt.minorticks_on()
            

            
            plt.title('PMF')
            #plt.figure(2)
            #plt.hist(Y, bins = 40, label=r'$\Delta$x,y')
            #plt.ylabel('Frequency',fontsize=14)
            #plt.xlabel('$\Delta$z (nm) ',fontsize=14)

        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise 
    
                
 

                
plt.subplots_adjust(hspace=0.4) 

#plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/LPP_PMF_Caff_Dpg_.png',dpi=300,bbox_inches='tight',pad_inches=0.20)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob 
import errno 
import itertools
plt.figure(figsize=(20,11))

 
 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/PMF/PMF_LPP_LPPLor/')
with open('data.txt', 'w') as file:
    
    path = './fes_all.dat' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["b", "r", "b","r","c","m"])
for name in sorted(glob.glob('fes_*2mr.dat')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name)
       
            X=f[:,0]
            Y=f[:,1]*(-1)
            Z=f[:,2]
            
            plt.subplot(2, 3, 1)
            plt.plot(X,Y,':ro',label=name,color=next(colors))
            #plt.errorbar(X,Y, yerr=Z, label='both limits (default)')


            plt.ylabel('PMF (kJ/mol)',fontsize=14)
            plt.xlabel('Z direction (nm)',fontsize=14)
            plt.ylim(0, 60)
            plt.xlim(-5, 6)
            plt.legend(loc='center top')
            plt.minorticks_on()
            

            
            plt.title('PMF')
            #plt.figure(2)
            #plt.hist(Y, bins = 40, label=r'$\Delta$x,y')
            #plt.ylabel('Frequency',fontsize=14)
            #plt.xlabel('$\Delta$z (nm) ',fontsize=14)

        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise 
    
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/PMF/PMF_LPP_LPPLor/')
with open('data.txt', 'w') as file:
    
    path = './fes_all.dat' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["b", "r", "b","r","c","m"])
for name in sorted(glob.glob('fes_*dpg.dat')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name)
       
            X=f[:,0]
            Y=f[:,1]*(-1)
            Z=f[:,2]
            
            plt.subplot(2, 3, 2)
            plt.plot(X,Y,':ro',label=name,color=next(colors))
            #plt.errorbar(X,Y, yerr=Z, label='both limits (default)')


            plt.ylabel('PMF (kJ/mol)',fontsize=14)
            plt.xlabel('Z direction (nm)',fontsize=14)
            plt.ylim(0,60)
            plt.xlim(-5, 6)
            plt.legend(loc='center top')
            plt.minorticks_on()
            

            
            plt.title('PMF')
            #plt.figure(2)
            #plt.hist(Y, bins = 40, label=r'$\Delta$x,y')
            #plt.ylabel('Frequency',fontsize=14)
            #plt.xlabel('$\Delta$z (nm) ',fontsize=14)

        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise                 
plt.subplots_adjust(hspace=0.4) 

plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/LPP_Lor_PMF.png',dpi=300,bbox_inches='tight',pad_inches=0.20)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob 
import errno 
import itertools
plt.figure(figsize=(20,11))

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib import pyplot as plt

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/')
with open('data.txt', 'w') as file:
    
    path = './fes_all.dat' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["b", "r", "black","r","c","m"])
for name in sorted(glob.glob('LogP.dat')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name)
       
            X=f[:,0]
            Y=f[:,1]
            Y2=f[:,5]
      
            
            
            X = X.reshape(-1,1)

            plt.subplot(2, 3, 1)
            plt.plot(X,Y,'ro',label='Slab,R$^{2}$=0.64',color=next(colors))
            plt.plot(X,Y2,'ro',label='Bilayer,R$^{2}$=0.59',color=next(colors))

            #plt.errorbar(X,Y, yerr=Z, label='both limits (default)')


            plt.ylabel('Barrier $\Delta G^{\u2021}$ (kJ/mol)',fontsize=14)
            plt.xlabel('Log P',fontsize=14)
            plt.ylim(0, 50)
            plt.xlim(-1, 4)
            plt.legend(loc='center top',fontsize=18)
            plt.minorticks_on()
    
            plt.title('Log P vs. Barrier')
            
 
            # Initialize the model
            model = LinearRegression()
            # Train the model - fit the data to the model
            model.fit(X, Y)
            
            # Predict
            y_predicted = model.predict(X)

            # model evaluation
            rmse = mean_squared_error(Y, y_predicted)
            r2 = r2_score(Y, y_predicted)

            # printing values
            print('Slope:' ,model.coef_)
            print('Intercept:', model.intercept_)
            print('Root mean squared error: ', rmse)
            print('R2 score: ', r2)
            model2 = LinearRegression()
            # Train the model - fit the data to the model
            model2.fit(X, Y2)
            
            # Predict
            y2_predicted = model.predict(X)

            # model evaluation
            rmse = mean_squared_error(Y2, y2_predicted)
            r2 = r2_score(Y2, y2_predicted)

            # printing values
            print('Slope:' ,model2.coef_)
            print('Intercept:', model2.intercept_)
            print('Root mean squared error: ', rmse)
            print('R2 score: ', r2)
             
           

            
            # plotting values
            #plt.scatter(X, Y, s=5)
         

            # predicted values
           
            plt.plot(X, y_predicted, color='r')
            #plt.plot(X, y2_predicted, color='b')
            #plt.plot(X, y3_predicted, color='black')

            


        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise 
    
plt.subplots_adjust(hspace=0.4) 
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/LogP_Barrier.png',dpi=300,bbox_inches='tight',pad_inches=0.20)
# Out:
# Slope: [-6.48815973]
# Intercept: 32.021784553474696
# Root mean squared error:  48.86781187122736
# R2 score:  0.6439827930335864
# Slope: [-5.64695868]
# Intercept: 26.185497600990562
# Root mean squared error:  28.718858148893357
# R2 score:  0.5803598842160259

# %%
import numpy as np
import pandas as pd
import colorsys

import matplotlib.pyplot as plt
import os
import glob 
import errno 
import itertools
plt.figure(figsize=(20,11))

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib import pyplot as plt

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/')
with open('data.txt', 'w') as file:
    
    path = './fes_all.dat' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "g", "b","y"])
    markers = itertools.cycle(["o","x","y","q"])
   

for name in sorted(glob.glob('LogP.dat')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name)
       
            X=f[:,0]
            Y=f[:,1]
            Y2=f[:,5]
      
            
            
            X = X.reshape(-1,1)

            plt.subplot(2, 3, 1)
            plt.plot(X,Y,'ro',label='Slab,R$^{2}$=0.64',marker=next(markers),c=next(colors))
            plt.plot(X,Y2,'ro',label='Bilayer,R$^{2}$=0.59',marker=next(markers),color=next(colors))

            #plt.errorbar(X,Y, yerr=Z, label='both limits (default)')


            plt.ylabel('Barrier $\Delta G^{\u2021}$ (kJ/mol)',fontsize=14)
            plt.xlabel('Log P',fontsize=14)
            plt.ylim(0, 50)
            plt.xlim(-1, 4)
            plt.legend(loc='center top',fontsize=18)
            plt.minorticks_on()
    
            plt.title('Log P vs. Barrier')
            
 
            # Initialize the model
            model = LinearRegression()
            # Train the model - fit the data to the model
            model.fit(X, Y)
            
            # Predict
            y_predicted = model.predict(X)

            # model evaluation
            rmse = mean_squared_error(Y, y_predicted)
            r2 = r2_score(Y, y_predicted)

            # printing values
            print('Slope:' ,model.coef_)
            print('Intercept:', model.intercept_)
            print('Root mean squared error: ', rmse)
            print('R2 score: ', r2)
            model2 = LinearRegression()
            # Train the model - fit the data to the model
            model2.fit(X, Y2)
            
            # Predict
            y2_predicted = model.predict(X)

            # model evaluation
            rmse = mean_squared_error(Y2, y2_predicted)
            r2 = r2_score(Y2, y2_predicted)

            # printing values
            print('Slope:' ,model2.coef_)
            print('Intercept:', model2.intercept_)
            print('Root mean squared error: ', rmse)
            print('R2 score: ', r2)
             
           

            
            # plotting values
            #plt.scatter(X, Y, s=5)
         

            # predicted values
           
            #plt.plot(X, y_predicted, color='r')
            #plt.plot(X, y2_predicted, color='b')
            #plt.plot(X, y3_predicted, color='black')

            


        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise 
    
plt.subplots_adjust(hspace=0.4) 
#plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/LogP_Barrier.png',dpi=300,bbox_inches='tight',pad_inches=0.20)
# Out:
# Slope: [-6.48815973]
# Intercept: 32.021784553474696
# Root mean squared error:  48.86781187122736
# R2 score:  0.6439827930335864
# Slope: [-5.64695868]
# Intercept: 26.185497600990562
# Root mean squared error:  28.718858148893357
# R2 score:  0.5803598842160259

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob 
import errno 
import itertools
plt.figure(figsize=(20,11))
 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/PMF/')
with open('data.txt', 'w') as file:
    
    path = './fes_all.dat' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["purple", "g", "b","r","c","m"])
for name in sorted(glob.glob('fes*')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name)
       
            X=f[:,0]
            Y=f[:,1]*(-1)
            Z=f[:,2]
            
            plt.subplot(2, 3, 1)
            plt.plot(X,Y,':ro',label=name,color=next(colors))
            #plt.errorbar(X,Y, yerr=Z, label='both limits (default)')


            plt.ylabel('PMF (kJ/mol)',fontsize=14)
            plt.xlabel('Z direction (nm)',fontsize=14)
            plt.ylim(0, 130)
            plt.xlim(-5, 5)
            plt.legend(loc='center')
            plt.minorticks_on()
            

            
            plt.title('PMF')
            
            
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise 
    
                
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/PMF')
with open('data.txt', 'w') as file:
    
    path = './all.txt' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["purple", "g", "b","r","c","m"])
for name in sorted(glob.glob('force*')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            f = np.loadtxt(name, max_rows=2000, skiprows=1)

            print('f')
            X=f[:,0]
            Y=f[:,1]*(-1)
         
            
            def smooth(y, box_pts):
                box = np.ones(box_pts)/box_pts
                y_smooth = np.convolve(y, box, mode='same')
                return y_smooth
            plt.subplot(2, 3, 2)
            #plt.plot(X,Y,':ro',label=name,color=next(colors))
            plt.plot(X,Y,':ro',label=name,color=next(colors))
            plt.ylabel('Average force (kJ/mol/nm)',fontsize=14)
            plt.xlabel('Z coordinate (nm)',fontsize=14)
            plt.ylim(-120, 120)
            #plt.errorbar(X,Y, yerr=0, label='both limits (default)')
            plt.title('Force')
            plt.legend(loc='upper right')
            plt.minorticks_on()


        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise
                

                
plt.subplots_adjust(hspace=0.4) 

plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/LPP_PMF_Caff_Dpg_.png',dpi=300,bbox_inches='tight',pad_inches=0.20)
# Out:
# f
# f
# f
# f

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob 
import errno 
import itertools
plt.figure(figsize=(20,11))
 
 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/PMF/')
with open('data.txt', 'w') as file:
    
    path = './fes_all.dat' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["red", "red", "b","b","c","m"])
    markers = itertools.cycle(["o","x","o","x"])
for name in sorted(glob.glob('fes*')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name)
       
            X=f[:,0]
            Y=f[:,1]*(-1)
            Z=f[:,2]
            
            plt.subplot(2, 3, 1)
            plt.plot(X,Y,':ro',label=name,marker=next(markers),color=next(colors))
            #plt.errorbar(X,Y, yerr=Z, label='both limits (default)')


            plt.ylabel('PMF (kJ/mol)',fontsize=14)
            plt.xlabel('Z direction (nm)',fontsize=14)
            plt.ylim(0, 110)
            plt.xlim(-5, 7)
            plt.legend(loc='upper center')
            plt.minorticks_on()
            

            
            plt.title('PMF')
            #plt.figure(2)
            #plt.hist(Y, bins = 40, label=r'$\Delta$x,y')
            #plt.ylabel('Frequency',fontsize=14)
            #plt.xlabel('$\Delta$z (nm) ',fontsize=14)

        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise 
    
                
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/PMF')
with open('data.txt', 'w') as file:
    
    path = './all.txt' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["red", "red", "b","b","c","m"])
for name in sorted(glob.glob('force*')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            f = np.loadtxt(name, max_rows=2000, skiprows=1)

            print('f')
            X=f[:,0]
            Y=f[:,1]*(-1)
         
            
            def smooth(y, box_pts):
                box = np.ones(box_pts)/box_pts
                y_smooth = np.convolve(y, box, mode='same')
                return y_smooth
            plt.subplot(2, 3, 2)
            #plt.plot(X,Y,':ro',label=name,color=next(colors))
            plt.plot(X,Y,':ro',label=name,color=next(colors))
            plt.ylabel('Average force (kJ/mol/nm)',fontsize=14)
            plt.xlabel('Z coordinate (nm)',fontsize=14)
            plt.ylim(-120, 120)
            plt.xlim(-5, 7)
            #plt.errorbar(X,Y, yerr=0, label='both limits (default)')
            plt.title('Force')
            plt.legend(loc='upper right')
            plt.minorticks_on()


        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise
                

                
plt.subplots_adjust(hspace=0.4) 

plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/LPP_PMF_Caff_2MR_Dpg_3.png',dpi=300,bbox_inches='tight',pad_inches=0.20)
# Out:
# f
# f
# f
# f

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob 
import errno 
import itertools
plt.figure(figsize=(20,11))
 
 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/PMF/CAFF_DPG')
with open('data.txt', 'w') as file:
    
    path = './fes_all.dat' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["red", "red", "b","b","c","m"])
    markers = itertools.cycle(["o","x","o","x"])
for name in sorted(glob.glob('fes*')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name)
       
            X=f[:,0]
            Y=f[:,1]*(-1)
            Z=f[:,2]
            
            plt.subplot(2, 3, 1)
            plt.plot(X,Y,':ro',label=name,marker=next(markers),color=next(colors))
            #plt.errorbar(X,Y, yerr=Z, label='both limits (default)')


            plt.ylabel('PMF (kJ/mol)',fontsize=14)
            plt.xlabel('Z direction (nm)',fontsize=14)
            plt.ylim(0, 130)
            plt.xlim(-5, 7)
            plt.legend(loc='top')
            plt.minorticks_on()
            

            
            plt.title('PMF')
            #plt.figure(2)
            #plt.hist(Y, bins = 40, label=r'$\Delta$x,y')
            #plt.ylabel('Frequency',fontsize=14)
            #plt.xlabel('$\Delta$z (nm) ',fontsize=14)

        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise 
    
                
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/PMF')
with open('data.txt', 'w') as file:
    
    path = './all.txt' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["red", "red", "b","b","c","m"])
for name in sorted(glob.glob('force*')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            f = np.loadtxt(name, max_rows=2000, skiprows=1)

            print('f')
            X=f[:,0]
            Y=f[:,1]*(-1)
         
            
            def smooth(y, box_pts):
                box = np.ones(box_pts)/box_pts
                y_smooth = np.convolve(y, box, mode='same')
                return y_smooth
            plt.subplot(2, 3, 2)
            #plt.plot(X,Y,':ro',label=name,color=next(colors))
            plt.plot(X,Y,':ro',label=name,color=next(colors))
            plt.ylabel('Average force (kJ/mol/nm)',fontsize=14)
            plt.xlabel('Z coordinate (nm)',fontsize=14)
            plt.ylim(-120, 120)
            plt.xlim(-5, 7)
            #plt.errorbar(X,Y, yerr=0, label='both limits (default)')
            plt.title('Force')
            plt.legend(loc='upper right')
            plt.minorticks_on()


        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise
                

                
plt.subplots_adjust(hspace=0.4) 

#plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/LPP_PMF_Caff_Dpg_.png',dpi=300,bbox_inches='tight',pad_inches=0.20)
# Out:
# f
# f
# f
# f

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob 
import errno 
import itertools
plt.figure(figsize=(20,11))
 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/PMF/PMF_LPP_LPPLor/2MR')
with open('data.txt', 'w') as file:
    path = './fes_all.dat' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["black", "red", "b","r","c","m"])
    markers =itertools.cycle(['o','v','d','s','D'])

for name in sorted(glob.glob('fes*')):
        try: 
            lines = open(name,'r')
            f = np.loadtxt(name)
            X=f[:,0]
            Y=f[:,1]*(-1)
            Z=f[:,2]
            plt.subplot(2, 3, 1)
            plt.plot(X,Y,':ro',label=name,color=next(colors),marker=next(markers)) 
            plt.ylabel('PMF (kJ/mol)',fontsize=14)
            plt.xlabel('Z direction (nm)',fontsize=14)
            plt.ylim(0, 60)
            plt.xlim(-5, 7)
            plt.legend(loc='best')
            plt.minorticks_on()
            plt.title('PMF')
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise 
    
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/PMF/PMF_LPP_LPPLor/2MR_DPG')
with open('data.txt', 'w') as file:
    path = './all.txt' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["black", "red", "b","r","c","m"])
    markers =itertools.cycle(['o','v','d','s','D'])

for name in sorted(glob.glob('fes*')):
        try: 
            lines = open(name,'r')
            f = np.loadtxt(name, max_rows=2000, skiprows=1)
            print('f')
            X=f[:,0]
            Y=f[:,1]*(-1)
            plt.subplot(2, 3, 2)
            plt.plot(X,Y,':ro',label=name,color=next(colors),marker=next(markers))
            plt.ylabel('PMF (kJ/mol)',fontsize=14)
            plt.xlabel('Z direction (nm)',fontsize=14)
            plt.ylim(0, 60)
            plt.xlim(-5, 7)
            plt.title('PMF')
            plt.legend(loc='upper right')
            plt.minorticks_on()

        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise 
    
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/PMF/PMF_LPP_LPPLor/DPG')
with open('data.txt', 'w') as file:
    path = './all.txt' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["black", "red", "b","r","c","m"])
    markers =itertools.cycle(['o','v','d','s','D'])
for name in sorted(glob.glob('fes*')):
        try: 
            lines = open(name,'r')
            f = np.loadtxt(name, max_rows=2000, skiprows=1)
            print('f')
            X=f[:,0]
            Y=f[:,1]*(-1)
            plt.subplot(2, 3, 3)
            plt.plot(X,Y,':ro',label=name,color=next(colors),marker=next(markers))
            plt.ylabel('PMF (kJ/mol)',fontsize=14)
            plt.xlabel('Z direction (nm)',fontsize=14)
            plt.ylim(0, 60)
            plt.xlim(-5, 7)
            plt.title('PMF')
            plt.legend(loc='upper left')
            plt.minorticks_on()
             
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise
plt.subplots_adjust(hspace=0.4) 

plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/LPP_LOR_PMF_2MR_Caff_Dpg_Compare.png',dpi=300,bbox_inches='tight',pad_inches=0.20)
# Out:
# f
# f
# f
# f

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob 
import errno 
import itertools
plt.figure(figsize=(20,11))

 
 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/PMF/PMF_Caff_Dpg_2MR/')
with open('data.txt', 'w') as file:
    
    path = './fes_all.dat' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "g", "b","y","gray","m"])
for name in sorted(glob.glob('fes*')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name)
       
            X=f[:,0]
            Y=f[:,1]*(-1)
            Z=f[:,2]
            
            plt.subplot(2, 3, 1)
            plt.plot(X,Y,':ro',label=name,color=next(colors))
            #plt.errorbar(X,Y, yerr=Z, label='both limits (default)')


            plt.ylabel('PMF (kJ/mol)',fontsize=14)
            plt.xlabel('Z direction (nm)',fontsize=14)
            plt.ylim(-5, 70)
            plt.xlim(-5, 7)
            #plt.legend(loc='best')
            plt.minorticks_on()
            plt.legend(loc='upper center')


            
            plt.title('LPP: Pulling')
            #plt.figure(2)
            #plt.hist(Y, bins = 40, label=r'$\Delta$x,y')
            #plt.ylabel('Frequency',fontsize=14)
            #plt.xlabel('$\Delta$z (nm) ',fontsize=14)
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise 
    
                
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/PMF/PMF_Caff_Dpg_2MR')
with open('data.txt', 'w') as file:
    
    path = './all.txt' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "g", "b","y","gray","m"])
for name in sorted(glob.glob('force*')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            f = np.loadtxt(name, max_rows=2000, skiprows=1)

            print('f')
            X=f[:,0]
            Y=f[:,1]*(-1)
         
            
            def smooth(y, box_pts):
                box = np.ones(box_pts)/box_pts
                y_smooth = np.convolve(y, box, mode='same')
                return y_smooth
            plt.subplot(2, 3, 2)
            #plt.plot(X,Y,':ro',label=name,color=next(colors))
            plt.plot(X,Y,':ro',label=name,color=next(colors))
            plt.ylabel('Average force (kJ/mol/nm)',fontsize=14)
            plt.xlabel('Z coordinate (nm)',fontsize=14)
            plt.ylim(-60, 100)
            plt.xlim(-5, 7)
            #plt.errorbar(X,Y, yerr=0, label='both limits (default)')
            plt.title('Force')
            plt.legend(loc='upper left')
            plt.minorticks_on()


        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise
                
 
plt.subplots_adjust(hspace=0.4)

plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/LPP_PMF_all_new.png',dpi=300,bbox_inches='tight',pad_inches=0.20)
# Out:
# f
# f
# f
# f
# f

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob 
import errno 
import itertools
plt.figure(figsize=(20,11))

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/LPP_Caff_5000eq_0.2/Force_prod/All_new')
with open('data.txt', 'w') as file:
    
    
    def moving_average(a, n=50000) :
        ret = np.cumsum(a, dtype=float)
        ret[n:] = ret[n:] - ret[:-n]
        return ret[n - 1:] / n


    
    path = './*pullx.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('prod_z_*_pullf.xvg')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name)
       
            X=f[:,0]
            Y=f[:,1]
            #Y_=moving_average(a)
            
            plt.subplot(2, 3, 4)
            plt.plot(X,Y,':ro',label=name,color=next(colors))

            plt.ylabel('Force (kJ/mol/nm)',fontsize=14)
            plt.xlabel('Block',fontsize=14)
            plt.ylim(-100, 150)
            plt.xlim(0, 200)
            #plt.legend(loc='best')
            plt.minorticks_on()

            plt.title('LPP: Pulling')
            #plt.figure(2)
            #plt.hist(Y, bins = 40, label=r'$\Delta$x,y')
            #plt.ylabel('Frequency',fontsize=14)
            #plt.xlabel('$\Delta$z (nm) ',fontsize=14)
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise 
 
                
 
plt.subplots_adjust(hspace=0.4)

#plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/LPP_PMF_all.png',dpi=300,bbox_inches='tight',pad_inches=0.20)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob 
import errno 
import itertools
plt.figure(figsize=(20,11))

 
 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/PMF/PMF_Caff_Dpg_2MR/')
with open('data.txt', 'w') as file:
    
    path = './fes_all.dat' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "g", "b","y","gray","m"])
    #markers =itertools.cycle([4,5,6,7,8,9])
    markers =itertools.cycle(['o','v','d','s','D'])
for name in sorted(glob.glob('fes*')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name)
       
            X=f[:,0]
            Y=f[:,1]*(-1)
            Z=f[:,2]
            
            plt.subplot(2, 3, 1)
            plt.plot(X,Y,':ro',label=name,color=next(colors),marker=next(markers))
            #plt.errorbar(X,Y, yerr=Z, label='both limits (default)')


            plt.ylabel('PMF (kJ/mol)',fontsize=14)
            plt.xlabel('Z direction (nm)',fontsize=14)
            plt.ylim(-5, 70)
            plt.xlim(-5, 7)
            #plt.legend(loc='best')
            plt.minorticks_on()
            plt.legend(loc='upper center')


            
            plt.title('LPP: Pulling')
            #plt.figure(2)
            #plt.hist(Y, bins = 40, label=r'$\Delta$x,y')
            #plt.ylabel('Frequency',fontsize=14)
            #plt.xlabel('$\Delta$z (nm) ',fontsize=14)
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise 
    
                
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/PMF/PMF_Caff_Dpg_2MR')
with open('data.txt', 'w') as file:
    
    path = './all.txt' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "g", "b","y","gray","m"])
    markers =itertools.cycle(['o','v','d','s','D'])

for name in sorted(glob.glob('force*')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            f = np.loadtxt(name, max_rows=2000, skiprows=1)

            print('f')
            X=f[:,0]
            Y=f[:,1]*(-1)
         
            
            def smooth(y, box_pts):
                box = np.ones(box_pts)/box_pts
                y_smooth = np.convolve(y, box, mode='same')
                return y_smooth
            plt.subplot(2, 3, 2)
            #plt.plot(X,Y,':ro',label=name,color=next(colors))
            plt.plot(X,Y,':ro',label=name,color=next(colors),marker=next(markers))
            plt.ylabel('Average force (kJ/mol/nm)',fontsize=14)
            plt.xlabel('Z coordinate (nm)',fontsize=14)
            plt.ylim(-60, 100)
            plt.xlim(-5, 7)
            #plt.errorbar(X,Y, yerr=0, label='both limits (default)')
            plt.title('Force')
            plt.legend(loc='upper left')
            plt.minorticks_on()


        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise
                
 
plt.subplots_adjust(hspace=0.4)

plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_LPP/LPP_PMF_all_new_markers.png',dpi=300,bbox_inches='tight',pad_inches=0.20)
# Out:
# f
# f
# f
# f
# f
