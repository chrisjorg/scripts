# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob  
import errno  
import itertools 
plt.figure(figsize=(20,10)) 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 1)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('3 wat / hg')
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/Order/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*.xvg')): 
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 2)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('1 wat/hg')
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/0.01Wat/Order/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 3)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('0.01 wat/ hg')
 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
             raise 

plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Order_wat.png',dpi=300,bbox_inches='tight',pad_inches=0.00)
plt.show()
# Out:
# <ipython-input-102-0af36a454aa4>:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2, 3, 1)
# <ipython-input-102-0af36a454aa4>:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2, 3, 1)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob  
import errno  
import itertools 
plt.figure(figsize=(22,10)) 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        
        avg.append(s)
        
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 1)
plt.bar(range(7), avg,label=name,color=next(colors))
plt.xticks(range(7), ['Cer1_L', 'Cer1_T', 'Cer1_S', 'Cer2_L', 'Cer2_S', 'Cer3_L', 'Cer3_S'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg S$_{cd}$',fontsize=14)
plt.title('3 wat / hg')


os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/Order/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        
        avg.append(s)
        
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 2)
plt.bar(range(7), avg,label=name,color=next(colors))
plt.xticks(range(7), ['Cer1_L', 'Cer1_T' ,'Cer1_S', 'Cer2_L', 'Cer2_S', 'Cer3_L', 'Cer3_S'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg S$_{cd}$',fontsize=14)
plt.title('1 wat / hg')

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/0.01Wat/Order/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        
        avg.append(s)
        
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 3)
plt.bar(range(7), avg,label=name,color=next(colors))
plt.xticks(range(7), ['Cer1_L', 'Cer1_T' ,'Cer1_S', 'Cer2_L', 'Cer2_S', 'Cer3_L', 'Cer3_S'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg S$_{cd}$',fontsize=14)
plt.title('0.01 wat / hg')



plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Order_histo_wat.png',dpi=300,bbox_inches='tight',pad_inches=0.00)
plt.show()
# Out:
# [0.2983819214285715, 0.020528415624999997, 0.3961518571428571, 0.30426031363636363, 0.31624871428571427, 0.30407676363636366, 0.31445899999999993]
# [0.27390317499999994, 0.048228425000000005, 0.3620090714285714, 0.23175775454545458, 0.24596752142857145, 0.2693128318181819, 0.28193657142857137]
# [0.2564090964285714, 0.045098168749999994, 0.30915528571428574, 0.15382015909090907, 0.17483775714285713, 0.19460568636363637, 0.2101884142857143]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob  
import errno  
import itertools 
plt.figure(figsize=(22,10)) 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order_leaflet/Upper_leaf_/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 5)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('Inner leaflet bottom')
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order_leaflet/Lower_leaf/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*.xvg')): 
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 2)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('Inner leaflet top')
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order_leaflet/Lower_leaf_/Python/')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 4)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('Outer leaflet bottom')
 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
             raise                 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order_leaflet/./Upper_leaf/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 1)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('Outer leaflet top')
 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
             raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order_leaflet/Slab/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 3)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('Slab')
 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
             raise 
#plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Order_parameter.png',dpi=300,bbox_inches='tight',pad_inches=0.00)
plt.show()
# Out:
# <ipython-input-115-e92924da9136>:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2, 3, 5)
# <ipython-input-115-e92924da9136>:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2, 3, 5)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob  
import errno  
import itertools 
plt.figure(figsize=(22,10)) 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order_leaflet/Inner_leaf_avg/')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*avg.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 2)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('3 Wat/hg: Inner leaflet')
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order_leaflet/Outer_leaf_avg/')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*avg.xvg')): 
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 1)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('3 Wat/hg: Outer leaflet')
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order_leaflet/Slab/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 3)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('3 Wat/hg: Slab')
 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
             raise 
#plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Order_parameter_3wat_avg_per_leaf.png',dpi=300,bbox_inches='tight',pad_inches=0.00)
plt.show()
# Out:
# <ipython-input-114-be6a5e8057f7>:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2, 3, 2)
# <ipython-input-114-be6a5e8057f7>:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2, 3, 2)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob  
import errno  
import itertools 
plt.figure(figsize=(20,10)) 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order_leaflet/Upper_leaf_/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        
        avg.append(s)
        
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 5)
plt.bar(range(6), avg,label=name,color=next(colors))
plt.xticks(range(6), ['Cer1_L', 'Cer1_S', 'Cer2_L', 'Cer2_S', 'Cer3_L', 'Cer3_S'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg S$_{cd}$',fontsize=14)
plt.title('Inner leaflet bottom')


os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order_leaflet/Lower_leaf/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        
        avg.append(s)
        
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 2)
plt.bar(range(6), avg,label=name,color=next(colors))
plt.xticks(range(6), ['Cer1_L', 'Cer1_S', 'Cer2_L', 'Cer2_S', 'Cer3_L', 'Cer3_S'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg S$_{cd}$',fontsize=14)
plt.title('Inner leaflet top')

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order_leaflet/Lower_leaf_/Python/')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        
        avg.append(s)
        
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 4)
plt.bar(range(6), avg,label=name,color=next(colors))
plt.xticks(range(6), ['Cer1_L', 'Cer1_S', 'Cer2_L', 'Cer2_S', 'Cer3_L', 'Cer3_S'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg S$_{cd}$',fontsize=14)
plt.title('Outer leaflet bottom')

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order_leaflet/Upper_leaf/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        
        avg.append(s)
        
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 1)
plt.bar(range(6), avg,label=name,color=next(colors))
plt.xticks(range(6), ['Cer1_L', 'Cer1_S', 'Cer2_L', 'Cer2_S', 'Cer3_L', 'Cer3_S'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg S$_{cd}$',fontsize=14)
plt.title('Outer leaflet top')

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order_leaflet/Slab/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        
        avg.append(s)
        
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 3)
plt.bar(range(4), avg,label=name,color=next(colors))
plt.xticks(range(4), ['Cer2_L', 'Cer2_S', 'Cer3_L', 'Cer3_S'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg S$_{cd}$',fontsize=14)
plt.title('Slab')


plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Order_histo.png',dpi=300,bbox_inches='tight',pad_inches=0.00)
plt.show()
# Out:
# [0.32971263181818183, 0.41600021428571426, 0.2249222727272727, 0.2352497857142857, 0.21831384090909092, 0.18601844999999997]
# [0.39091290909090903, 0.40962478571428573, 0.2399831136363636, 0.24834162142857144, 0.23662454545454548, 0.24359840714285713]
# [0.3275694045454546, 0.3770327142857143, 0.3232766636363637, 0.37501285714285715, 0.31397153181818177, 0.3771312142857143]
# [0.3764907272727273, 0.4152709999999999, 0.33174195000000006, 0.3951833571428571, 0.3412412377272727, 0.39576949999999994]
# [0.3128664636363636, 0.28748707142857144, 0.28065622272727275, 0.20966511428571427]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob  
import errno  
import itertools 
plt.figure(figsize=(22,10)) 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/Order/Analyze_per_leaf/Index_tcl/Upper_leaf_/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 5)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('Inner leaflet bottom')
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/Order/Analyze_per_leaf/Index_tcl/Lower_leaf/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*.xvg')): 
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 2)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('Inner leaflet top')
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/Order/Analyze_per_leaf/Index_tcl/Lower_leaf_/Python/')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 4)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('Outer leaflet bottom')
 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
             raise                 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/Order/Analyze_per_leaf/Index_tcl/Upper_leaf/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 1)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('Outer leaflet top')
 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
             raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/Order/Analyze_per_leaf/Index_tcl/Slab/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 3)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('Slab')
 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
             raise 
#plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Order_parameter_1Wat.png',dpi=300,bbox_inches='tight',pad_inches=0.00)
plt.show()
# Out:
# <ipython-input-113-efed1269f54c>:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2, 3, 5)
# <ipython-input-113-efed1269f54c>:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2, 3, 5)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob  
import errno  
import itertools 
plt.figure(figsize=(22,10)) 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/Order/Analyze_per_leaf/Index_tcl/Inner_leaf_avg/')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*avg.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 2)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('1 Wat/hg: Inner leaflet')
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/Order/Analyze_per_leaf/Index_tcl/Outer_leaf_avg/')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*avg.xvg')): 
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 1)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('1 Wat/hg: Outer leaflet')
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/Order/Analyze_per_leaf/Index_tcl/Slab/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 3)
        plt.plot(Y,':ro',label=name,color=next(colors))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=14)
        plt.xlabel('C atom',fontsize=14)
        plt.title('1 Wat/hg: Slab')
 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
             raise 
#plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Order_parameter_1wat_avg_per_leaf.png',dpi=300,bbox_inches='tight',pad_inches=0.00)
plt.show()
# Out:
# <ipython-input-112-ca9748c3d8b1>:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2, 3, 2)
# <ipython-input-112-ca9748c3d8b1>:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2, 3, 2)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import scipy
from scipy import stats 
import glob  
import errno  
import itertools 
plt.figure(figsize=(9,6)) 

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Avg_Order/Per_hydr/Outer')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        Z=scipy.stats.sem(Y)

        
        avg.append(s)
        
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 1)
plt.bar(range(3), avg,yerr=Z, label=name,color=( 0.2 , 0.4 , 0.6 , 0.6 ))
plt.xticks(range(3), ['0.01 w/hg', '1 w/hg', '3 w/hg'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg S$_{cd}$',fontsize=14)
plt.title('Outer leaflet')

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Avg_Order/Per_hydr/Inner')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        Z=scipy.stats.sem(Y)

        avg.append(s)
        
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 2)
plt.bar(range(3), avg,yerr=Z, label=name,color=( 0.2 , 0.4 , 0.6 , 0.6 ))
plt.xticks(range(3), ['0.01 w/hg', '1 w/hg', '3 w/hg'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg S$_{cd}$',fontsize=14)
plt.title('Inner leaflet')

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Avg_Order/Per_hydr/Slab')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        Z=scipy.stats.sem(Y)

        avg.append(s)
        
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 3)
plt.bar(range(3), avg,yerr=Z, label=name,color=( 0.2 , 0.4 , 0.6 , 0.6 ))
plt.xticks(range(3), ['0.01 w/hg', '1 w/hg', '3 w/hg'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg S$_{cd}$',fontsize=14)
plt.title('Slab')


plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Avg_Order/Avg_Order.png',dpi=300,bbox_inches='tight',pad_inches=0.15)
plt.show()
# Out:
# [0.20737166203703714, 0.33740151574074084, 0.3565279555555556]
# [0.1003856680555555, 0.22497993333333335, 0.27978702685185186]
# [0.06769718741379313, 0.1901572388888889, 0.2780226347222222]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import scipy
from scipy import stats 
import glob  
import errno  
import itertools 
plt.figure(figsize=(15,6)) 

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Model1/Avg_Order/Per_hydr/All')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        Z=scipy.stats.sem(Y)

        
        avg.append(s)
        err.append(Z)

        
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
print(err)

#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 1)
namez = ('Inner')
plt.bar(range(9), avg,yerr=Z, label=namez,color=( 'lightcoral', 'lightcoral', 'lightcoral', 'lightblue', 'lightblue', 'lightblue', 'gray', 'gray', 'gray' ))
plt.xticks(range(9), ['0.01 w', '1 w', '3 w','0.01 w', '1 w', '3 w','0.01 w', '1 w', '3 w'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg -S$_{cd}$',fontsize=14)
plt.title('Order parameter by hydration state')
plt.minorticks_on()
list = ('Inner','Outer','Slab')
plt.legend()
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

AP = mpatches.Patch(color='lightcoral', label='Inner')
NA = mpatches.Patch(color='lightblue', label='Outer')
SA = mpatches.Patch(color='gray', label='Slab')
plt.legend(handles=[AP,NA,SA], loc=2)



plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Avg_Order/Avg_Order.png',dpi=300,bbox_inches='tight',pad_inches=0.15)
plt.show()
# Out:
# [0.1003856680555555, 0.22497993333333335, 0.2780226347222222, 0.20737166203703714, 0.33740151574074084, 0.3565279555555556, 0.06769718741379313, 0.1901572388888889, 0.2780226347222222]
# [0.010844741067954064, 0.011041732928713155, 0.009813555671188372, 0.010593415482057143, 0.010643479548620896, 0.009664091076129021, 0.009428509928110316, 0.009673940637049997, 0.009813555671188372, 0.004989418636083599, 0.010459475439752895, 0.009673940637049997, 0.009689069272177641, 0.01036863325799546, 0.010643479548620896, 0.004019981850917627, 0.007197033022482804, 0.009673940637049997, 0.004989418636083599, 0.010459475439752895, 0.009673940637049997, 0.009689069272177641, 0.01036863325799546, 0.010643479548620896, 0.004019981850917627, 0.007197033022482804, 0.009673940637049997]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import itertools 

plt.figure(figsize=(12,6)) 
colors = itertools.cycle(['lightcoral', 'lightblue','gray', 'lightblue', 'lightcoral', 'gray'])
 



colors = itertools.cycle(['lightcoral', 'lightblue','gray', 'lightblue', 'lightcoral', 'gray'])

plt.subplot(1, 3, 1)

bla2 = ['0.01 w', '1 w', '3 w']

plt.gca().invert_xaxis()
InnerMean =  np.array([0.10, 0.225, 0.278])
OuterMean =  np.array([0.2073, 0.3374, 0.35652])
SlabMean =  np.array([0.0676, 0.1901, 0.278]) 
StdInner =   np.array([0.01, 0.01 , 0.01])
StdOuter =   np.array([0.01 , 0.01 , 0.01])
StdSlab =   np.array([0.01, 0.01, 0.01]) 
ind = [bla for bla in bla2]   # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, InnerMean, width, label='0.01 w', yerr=StdInner,color=next(colors))
p2 = plt.bar(ind, OuterMean, width, bottom=InnerMean, yerr=StdOuter, color=next(colors))
p3 = plt.bar(ind, SlabMean, width, bottom=InnerMean+OuterMean, yerr=StdSlab, color=next(colors))

plt.ylabel('Avg -S$_{cd}$', fontsize=14)
plt.title('Order parameter by hydration state', fontsize=14)
plt.xticks(ind, ('0.01 w', '1 w', '3 w'), fontsize=14)
plt.yticks(np.arange(0, 9, 0.1), fontsize=14)
plt.legend((p1[0], p2[0], p3[0]), ('Inner', 'Outer', 'Slab'), fontsize=11)
plt.ylim(0, 1)

plt.minorticks_on()


plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Avg_Order/Avg_Order_Histogram.png',dpi=300,bbox_inches='tight',pad_inches=0.55)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob  
import errno  
import itertools 
plt.figure(figsize=(18,10)) 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/Order/Analyze_per_leaf/Index_tcl/Inner_leaf_avg/')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    mark = itertools.cycle(['o','v','o','v','o','v'])
    colors = itertools.cycle([ 'b','b',"green","green","purple",'purple'])

for name in sorted(glob.glob('Cer*avg.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 2)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.title('1 Wat/hg: Inner leaflet',fontsize=22)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/Order/Analyze_per_leaf/Index_tcl/Outer_leaf_avg/')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    mark = itertools.cycle(['o','v','o','v','o','v'])
    colors = itertools.cycle([ 'b','b',"green","green","purple",'purple'])

    
for name in sorted(glob.glob('Cer*avg.xvg')): 
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 1)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.title('1 Wat/hg: Outer leaflet',fontsize=22)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/Order/Analyze_per_leaf/Index_tcl/Slab/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["green","green","purple",'purple'])
    mark = itertools.cycle(['o','v','o','v','o','v'])

for name in sorted(glob.glob('Cer*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 3)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.title('1 Wat/hg: Slab',fontsize=22)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
 
 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
             raise 
plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Order_parameter_1wat_avg_per_leaf.png',dpi=300,bbox_inches='tight',pad_inches=0.40)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob  
import errno  
import itertools 
plt.figure(figsize=(18,10)) 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order_leaflet/Inner_leaf_avg/')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    mark = itertools.cycle(['o','v','o','v','o','v'])
    colors = itertools.cycle([ 'b','b',"green","green","purple",'purple'])

for name in sorted(glob.glob('Cer*avg.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 2)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.title('3 Wat/hg: Inner leaflet',fontsize=22)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order_leaflet/Outer_leaf_avg/')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    mark = itertools.cycle(['o','v','o','v','o','v'])
    colors = itertools.cycle([ 'b','b',"green","green","purple",'purple'])
    
for name in sorted(glob.glob('Cer*avg.xvg')): 
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 1)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)

        plt.title('3 Wat/hg: Outer leaflet',fontsize=22)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order_leaflet/Slab/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ "green","green","purple",'purple'])
    mark = itertools.cycle(['o','v','o','v','o','v'])

for name in sorted(glob.glob('Cer*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 3)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.title('3 Wat/hg: Slab',fontsize=22)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
             raise 
plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Order_parameter_3wat_avg_per_leaf.png',dpi=300,bbox_inches='tight',pad_inches=0.40)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob  
import errno  
import itertools 
plt.figure(figsize=(18,10)) 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ 'b','b',"b","green","green","purple",'purple'])
    mark = itertools.cycle(['o','.','v','o','v','o','v'])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 1)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.title('3 wat / hg',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/Order/Analyze_avg/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ 'b','b',"b","green","green","purple",'purple'])
    mark = itertools.cycle(['o','.','v','o','v','o','v'])
for name in sorted(glob.glob('*.xvg')): 
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 2)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.title('1 wat/hg',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/0.01Wat/Order/Analyse_avg/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ 'b','b',"b","green","green","purple",'purple'])
    mark = itertools.cycle(['o','.','v','o','v','o','v'])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 3)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.title('0.01 wat/ hg',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)

 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
             raise 

plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Order_wat.png',dpi=300,bbox_inches='tight',pad_inches=0.40)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob  
import errno  
import itertools 
plt.figure(figsize=(18,10)) 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_3wat/Analyse_XV/310K/Analyse_avg/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ 'b','r',"b","r","green","purple",'purple'])
    mark = itertools.cycle(['o','.','v','o','v','o','v'])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 1)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.title('Asym; Avg. order by temp',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 



os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_3wat/Analyse_XV/SymNoSym/Sym')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ 'b','r',"b","r","green","purple",'purple'])
    mark = itertools.cycle(['o','.','v','o','v','o','v'])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 2)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.title('Per leaflet (310 K; Sym water) ',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
            
            
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_3wat/Analyse_XV/SymNoSym/NoSym')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ 'b','r',"b","r","green","purple",'purple'])
    mark = itertools.cycle(['o','.','v','o','v','o','v'])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 3)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.title('Per leaflet (310 K; Asym water)',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 

            
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_3wat/Analyse_XV/SymNoSym/Sym/Avg')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ 'r','r',"b","b","green","purple",'purple'])
    mark = itertools.cycle(['o','.','v','o','v','o','v'])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 5)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.title('Per leaflet (310 K; Sym water) ',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
            
            
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_3wat/Analyse_XV/SymNoSym/NoSym/Avg')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ 'r','r',"b","b","green","purple",'purple'])
    mark = itertools.cycle(['o','.','v','o','v','o','v'])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 6)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.title('Per leaflet (310 K; Asym water)',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
        
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_3wat/Analyse_XV/350K/Analyse_per_leaf/NoSym_350')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ 'r','r',"b","b","green","purple",'purple'])
    mark = itertools.cycle(['o','.','v','o','v','o','v'])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 4)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.title('Per leaflet (350 K, Asym. wat)',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 


plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Z_3wat/Analyse_XV/Order_sym_temp.png',dpi=300,bbox_inches='tight',pad_inches=0.40)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob  
import errno  
import itertools 
plt.figure(figsize=(18,10)) 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ 'b','b',"b","green","green","purple",'purple'])
    mark = itertools.cycle(['o','.','v','o','v','o','v'])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 1)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.title('3 wat / hg (LPP)',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Model2/3Wat/gromacs2/Analyse_Model2/Order/Analyse_avg/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ 'b','b',"b","green","green","purple",'purple',"red",'red'])
    mark = itertools.cycle(['o','.','v','o','v','o','v','o','v'])
for name in sorted(glob.glob('*.xvg')): 
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 3)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.title('3 wat/hg (LPP$_{L}$)',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/DPG/DPG_LPP/NEW/RUN_90_10/Analysis/Order/Analyse_avg/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ 'b','b',"b","green","green","purple",'purple'])
    mark = itertools.cycle(['o','.','v','o','v','o','v'])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 2)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.title('LPP + DPG',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)

 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
             raise 

plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Order_Model_1_2_DPG.png',dpi=300,bbox_inches='tight',pad_inches=0.40)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob  
import errno  
import itertools 
plt.figure(figsize=(18,10)) 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Order/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ 'b','b',"b","green","green","purple",'purple'])
    mark = itertools.cycle(['o','.','v','o','v','o','v'])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 1)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.title('3 wat / hg (LPP)',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/Model2/3Wat/gromacs2/Analyse_Model2/Order/Analyse_avg/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ 'b','b',"b","green","green","purple",'purple',"red",'red'])
    mark = itertools.cycle(['o','.','v','o','v','o','v','o','v'])
for name in sorted(glob.glob('*.xvg')): 
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 3)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.title('3 wat/hg (LPP_l)',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/DPG/DPG_LPP/NEW/RUN_90_10/Analysis/Order/Analyse_avg_repeat/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ 'b','b',"b","green","green","purple",'purple'])
    mark = itertools.cycle(['o','.','v','o','v','o','v'])
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 2)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.title('LPP + DPG',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)

 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
             raise 


plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Order_Model_1_2_DPG_repeat.png',dpi=300,bbox_inches='tight',pad_inches=0.40)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob  
import errno  
import itertools 
plt.figure(figsize=(18,10)) 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/DPG/DPG_LPP/NEW/RUN_90_10/Analysis/Order/Analyse_per_leaf/Inner_leaf_avg/')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    mark = itertools.cycle(['o','v','o','v','o','v'])
    colors = itertools.cycle([ 'b','b',"green","green","purple",'purple'])

for name in sorted(glob.glob('Cer*avg.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 2)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.title('LPP+DPG: Inner leaflet',fontsize=22)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/DPG/DPG_LPP/NEW/RUN_90_10/Analysis/Order/Analyse_per_leaf/Outer_leaf_avg/')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    mark = itertools.cycle(['o','v','o','v','o','v'])
    colors = itertools.cycle([ 'b','b',"green","green","purple",'purple'])
    
for name in sorted(glob.glob('Cer*avg.xvg')): 
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 1)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)

        plt.title('LPP+DPG: Outer leaflet',fontsize=22)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/DPG/DPG_LPP/NEW/RUN_90_10/Analysis/Order/Analyse_per_leaf/Slab/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ "green","green","purple",'purple'])
    mark = itertools.cycle(['o','v','o','v'])

for name in sorted(glob.glob('Cer*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 3)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.title('LPP+DPG: Slab',fontsize=22)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
             raise 
plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Order_parameter_DPG_leaflet.png',dpi=300,bbox_inches='tight',pad_inches=0.40)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob  
import errno  
import itertools 
plt.figure(figsize=(18,10)) 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/DPG/DPG_LPP/NEW/RUN_90_10/Analysis/Order/Analyse_per_leaf_repeat/Inner_leaf_avg/')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    mark = itertools.cycle(['o','v','o','v','o','v'])
    colors = itertools.cycle([ 'b','b',"green","green","purple",'purple'])

for name in sorted(glob.glob('Cer*avg.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 2)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.title('LPP+DPG: Inner leaflet',fontsize=22)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/DPG/DPG_LPP/NEW/RUN_90_10/Analysis/Order/Analyse_per_leaf_repeat/Outer_leaf_avg/')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    mark = itertools.cycle(['o','v','o','v','o','v'])
    colors = itertools.cycle([ 'b','b',"green","green","purple",'purple'])
    
for name in sorted(glob.glob('Cer*avg.xvg')): 
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 1)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)

        plt.title('LPP+DPG: Outer leaflet',fontsize=22)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/DPG/DPG_LPP/NEW/RUN_90_10/Analysis/Order/Analyse_per_leaf_repeat/Slab/Python')
with open('data.txt', 'w') as file:
    path = './*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle([ "green","green","purple",'purple'])
    mark = itertools.cycle(['o','v','o','v'])

for name in sorted(glob.glob('Cer*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 3, 3)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0, 0.5)
        plt.title('LPP+DPG: Slab',fontsize=22)
        plt.ylabel('$-S_{cd}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
             raise 
plt.tight_layout() 
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Order_parameter_DPG_leaflet',dpi=300,bbox_inches='tight',pad_inches=0.40)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import glob  
import errno  
import itertools 
plt.figure(figsize=(22,10)) 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Model1/3Wat/Order/Plot_rel')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    mark = itertools.cycle(['o','v','d','v','o','v'])
    colors = itertools.cycle([ 'b','b','b',"red","red","green",'green'])

for name in sorted(glob.glob('*_.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   

        from pathlib import Path
        a = print(name)
        b = str(print(name))
        name = Path(name).stem
        
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 4, 1)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(0.725, 1.3)
        plt.title('Tail avg. (LPP vs. LPP+DPG)',fontsize=22)
        plt.ylabel('$S_{cd(LPP+DPG)}/S_{cd(LPP)}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
        plt.minorticks_on()
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Model1/3Wat/Order_leaflet/Plot_rel_')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    mark = itertools.cycle(['o','v','o','v','o','v'])
    colors = itertools.cycle([ 'b','b','r',"r","green","green","purple",'purple'])

for name in sorted(glob.glob('*inner.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   

        from pathlib import Path
        a = print(name)
        b = str(print(name))
        name = Path(name).stem
        
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 4, 2)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(.725, 1.3)
        plt.title('Inner Leaf (LPP vs. LPP+DPG)',fontsize=22)
        plt.ylabel('$S_{cd(LPP+DPG)}/S_{cd(LPP)}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
        plt.minorticks_on()
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Model1/3Wat/Order_leaflet/Plot_rel_')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    mark = itertools.cycle(['o','v','o','v','o','v'])
    colors = itertools.cycle([ 'b','b','r',"r","green","green","purple",'purple'])

for name in sorted(glob.glob('*outer.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)

        from pathlib import Path
        a = print(name)
        b = str(print(name))
        name = Path(name).stem
        
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 4, 3)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(.725, 1.3)
        plt.title('Outer Leaf (LPP vs. LPP+DPG)',fontsize=22)
        plt.ylabel('$S_{cd(LPP+DPG)}/S_{cd(LPP)}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
        plt.minorticks_on()

    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise
            
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Model1/3Wat/Order_leaflet/Plot_rel_')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    mark = itertools.cycle(['o','v','o','v','o','v'])
    colors = itertools.cycle(['r','r','green',"green","green","green","purple",'purple'])

for name in sorted(glob.glob('*slab_.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        from pathlib import Path
        a = print(name)
        b = str(print(name))
        name = Path(name).stem
        
        X=f[:,0]
        Y=f[:,1]

        plt.subplot(2, 4, 4)
        plt.plot(Y,':ro',label=name,color=next(colors),marker=next(mark))
        plt.legend(loc='best')
        plt.xlim(0, 30)
        plt.ylim(.725, 1.3)
        plt.title('Slab (LPP vs. LPP+DPG)',fontsize=22)
        plt.ylabel('$S_{cd(LPP+DPG)}/S_{cd(LPP)}$',fontsize=22)
        plt.xlabel('C atom',fontsize=22)
        plt.tick_params(axis="x", labelsize=22)
        plt.tick_params(axis="y", labelsize=22)
        plt.minorticks_on()
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise
plt.tight_layout() 
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Order_parameter_DPG_ratio',dpi=300,bbox_inches='tight',pad_inches=0.40)
plt.show()
# Out:
# Cer1_Long_.xvg
# Cer1_Long_.xvg
# Cer1_Long_tail_.xvg
# Cer1_Long_tail_.xvg
# Cer1_Short_.xvg
# Cer1_Short_.xvg
# Cer2_Long_.xvg
# Cer2_Long_.xvg
# Cer2_Short_.xvg
# Cer2_Short_.xvg
# Cer3_Long_.xvg
# Cer3_Long_.xvg
# Cer3_Short_.xvg
# Cer3_Short_.xvg
# Cer1_Long_inner.xvg
# Cer1_Long_inner.xvg
# Cer1_Short_inner.xvg
# Cer1_Short_inner.xvg
# Cer2_Long_inner.xvg
# Cer2_Long_inner.xvg
# Cer2_Short_inner.xvg
# Cer2_Short_inner.xvg
# Cer3_Long_inner.xvg
# Cer3_Long_inner.xvg
# Cer3_Short_inner.xvg
# Cer3_Short_inner.xvg
# Cer1_Long_outer.xvg
# Cer1_Long_outer.xvg
# Cer1_Short_outer.xvg
# Cer1_Short_outer.xvg
# Cer2_Long_outer.xvg
# Cer2_Long_outer.xvg
# Cer2_Short_outer.xvg
# Cer2_Short_outer.xvg
# Cer3_Long_outer.xvg
# Cer3_Long_outer.xvg
# Cer3_Short_outer.xvg
# Cer3_Short_outer.xvg
# Cer2_Long_slab_.xvg
# Cer2_Long_slab_.xvg
# Cer2_Short_slab_.xvg
# Cer2_Short_slab_.xvg
# Cer3_Long_slab_.xvg
# Cer3_Long_slab_.xvg
# Cer3_Short_slab_.xvg
# Cer3_Short_slab_.xvg

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import scipy
from scipy import stats 
import glob  
import errno  
import itertools 
plt.figure(figsize=(12,6)) 

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Avg_Order/Per_model/Avg')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
    err=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        Z=scipy.stats.sem(Y)

        
        avg.append(s)
        err.append(Z)
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
print(err)
#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 1)
namez = ('Inner')
plt.bar(range(4), avg,yerr=Z, label=namez,color=( 'lightcoral', 'lightblue','gray','lightyellow' ))
plt.xticks(range(4), ['LPP$_{L}$', 'LPP', 'LPP+DPG','LPP$_{L}$+DPG'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg -S$_{cd}$',fontsize=14)
plt.title('Order parameter per model')
plt.minorticks_on()
plt.legend()
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

AP = mpatches.Patch(color='lightcoral')
NA = mpatches.Patch(color='lightblue')
SA = mpatches.Patch(color='gray')
plt.legend(handles=[AP,NA,SA], loc=2)
plt.tick_params(direction='inout', top=True, right=True, labeltop=False, labelright=False)


plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Avg_Order_Model.png',dpi=300,bbox_inches='tight',pad_inches=0.15)
plt.show()
# Out:
# [0.26582628283132526, 0.26018992781578953, 0.3081237770833332, 0.2754592988888889]
# [0.010763045276707897, 0.011454899808445192, 0.006600845429304913, 0.00755798533884961]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import scipy
from scipy import stats 
import glob  
import errno  
import itertools 
plt.figure(figsize=(9,6)) 

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Avg_Order/Per_model/Avg_')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
    err=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        Z=scipy.stats.sem(Y)

        
        avg.append(s)
        err.append(Z)
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
print(err)
#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 1)
namez = ('Inner')
plt.bar(range(2), avg,yerr=Z, label=namez,color=( 'lightcoral', 'lightblue' ))
plt.xticks(range(2), ['LPP$_{L}$', 'LPP'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg -S$_{cd}$',fontsize=14)
plt.title('Order parameter per model')
plt.minorticks_on()
plt.legend()
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

AP = mpatches.Patch(color='lightcoral')
NA = mpatches.Patch(color='lightblue')
SA = mpatches.Patch(color='gray')
plt.legend(handles=[AP,NA,SA], loc=2)



plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Avg_Order/Per_model/Avg_Order_Model_.png',dpi=300,bbox_inches='tight',pad_inches=0.15)
plt.show()
# Out:
# [0.26582628283132526, 0.3081237770833332]
# [0.010763045276707897, 0.006600845429304913]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import scipy
from scipy import stats 
import glob  
import errno  
import itertools 
plt.figure(figsize=(18,6)) 

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Avg_Order/Per_model/Per_leaf')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
    err=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        Z=scipy.stats.sem(Y)

        
        avg.append(s)
        err.append(Z)

        
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
print(err)

#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 1)
namez = ('Inner')
plt.bar(range(9), avg,yerr=Z, label=namez,color=( 'lightcoral', 'lightcoral', 'lightcoral', 'lightblue', 'lightblue', 'lightblue', 'gray', 'gray', 'gray' ))
plt.xticks(range(9), ['LPP/DPG', 'LPP', 'LPP$_{L}$','LPP+DPG', 'LPP', 'LPP$_{L}$','LPP/DPG', 'LPP', 'LPP$_{L}$'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg -S$_{cd}$',fontsize=14)
plt.title('Order parameter by model')
plt.minorticks_on()
list = ('Inner','Outer','Slab')
plt.legend()
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

AP = mpatches.Patch(color='lightcoral', label='Inner')
NA = mpatches.Patch(color='lightblue', label='Outer')
SA = mpatches.Patch(color='gray', label='Slab')
plt.legend(handles=[AP,NA,SA], loc=2)



plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Avg_Order_Per_Model_Leaf.png',dpi=300,bbox_inches='tight',pad_inches=0.15)
plt.show()
# Out:
# [0.2654621814814816, 0.27978702685185186, 0.2316300448275863, 0.35509188981481477, 0.3565279555555556, 0.35211329999999985, 0.290454975, 0.2780226347222222, 0.2316300448275863]
# [0.010844741067954064, 0.011041732928713155, 0.009813555671188372, 0.010593415482057143, 0.010643479548620896, 0.009664091076129021, 0.009428509928110316, 0.009673940637049997, 0.009813555671188372]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import scipy
from scipy import stats 
import glob  
import errno  
import itertools 
plt.figure(figsize=(12,6)) 

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Avg_Order/Per_model/Per_leaf_')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
    err=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        Z=scipy.stats.sem(Y)

        
        avg.append(s)
        err.append(Z)

        
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
print(err)

#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 1)
namez = ('Inner')
plt.bar(range(6), avg,yerr=Z, label=namez,color=( 'lightcoral',  'lightcoral', 'lightblue','lightblue', 'gray', 'gray' ))
plt.xticks(range(6), [ 'LPP', 'LPP$_{L}$', 'LPP', 'LPP$_{L}$', 'LPP', 'LPP$_{L}$'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg -S$_{cd}$',fontsize=14)
plt.title('Order parameter by model')
plt.minorticks_on()
list = ('Inner','Outer','Slab')
plt.legend()
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

AP = mpatches.Patch(color='lightcoral', label='Inner')
NA = mpatches.Patch(color='lightblue', label='Outer')
SA = mpatches.Patch(color='gray', label='Slab')
plt.legend(handles=[AP,NA,SA], loc=2)



plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Avg_Order_Per_Model_Leaf_.png',dpi=300,bbox_inches='tight',pad_inches=0.15)
plt.show()
# Out:
# [0.27978702685185186, 0.2316300448275863, 0.3565279555555556, 0.35211329999999985, 0.2780226347222222, 0.2316300448275863]
# [0.011041732928713155, 0.009813555671188372, 0.010643479548620896, 0.009664091076129021, 0.009673940637049997, 0.009813555671188372]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import os 
import scipy
from scipy import stats 
import glob  
import errno  
import itertools 
plt.figure(figsize=(31,6)) 

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Avg_Order/Per_model/Per_leaf')
with open('data.txt', 'w') as file:
    path = './*.xvg'
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
    avg=[]
    err=[]
for name in sorted(glob.glob('*.xvg')):
    try: 
        lines = open(name,'r')
        f = np.loadtxt(name)
   
        X=f[:,0]
        Y=f[:,1]
        s=sum(Y)/len(Y)
        Z=scipy.stats.sem(Y)

        
        avg.append(s)
        err.append(Z)

        
        
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise 
print(avg)
print(err)

#plt.bar(range(6), s/len(Y),label=name,color=next(colors))
plt.subplot(2, 3, 1)
namez = ('Inner')
plt.bar(range(12), avg,yerr=Z, label=namez,color=( 'lightcoral', 'lightcoral', 'lightcoral', 'lightcoral', 'lightblue', 'lightblue', 'lightblue', 'lightblue', 'gray', 'gray', 'gray', 'gray' ))
plt.xticks(range(12), ['LPP+DPG', 'LPP', 'LPP$_{L}$+DPG', 'LPP$_{L}$','LPP+DPG', 'LPP', 'LPP$_{L}$+DPG', 'LPP$_{L}$', 'LPP+DPG', 'LPP', 'LPP$_{L}$+DPG', 'LPP$_{L}$'])
        #plt.xlim(0, 30)
plt.ylim(0, 0.5)
plt.ylabel('Avg -S$_{cd}$',fontsize=14)
plt.title('Order parameter by model')
plt.minorticks_on()
list = ('Inner','Outer','Slab')
plt.legend()
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

AP = mpatches.Patch(color='lightcoral', label='Inner')
NA = mpatches.Patch(color='lightblue', label='Outer')
SA = mpatches.Patch(color='gray', label='Slab')
plt.legend(handles=[AP,NA,SA], loc=2)



plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Avg_Order_Per_Model_Leaf.png',dpi=300,bbox_inches='tight',pad_inches=0.15)
plt.show()
# Out:
# [0.2654621814814816, 0.27978702685185186, 0.26921441305555577, 0.2316300448275863, 0.35509188981481477, 0.3565279555555556, 0.3541340055555556, 0.35211329999999985, 0.290454975, 0.2780226347222222, 0.2508906206896552, 0.2316300448275863]
# [0.010844741067954064, 0.011041732928713155, 0.008612903043611626, 0.009813555671188372, 0.010593415482057143, 0.010643479548620896, 0.00985183632903282, 0.009664091076129021, 0.009428509928110316, 0.009673940637049997, 0.010125711300678138, 0.009813555671188372]
