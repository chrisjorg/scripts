# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob 
import errno 
import itertools
from scipy import integrate
plt.figure(figsize=(22,22))
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Hbond/Data')
with open('data.txt', 'w') as file:
    
    path = '*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('cer2*.xvg')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name,skiprows=25)
       
            X=f[:,0]
            X_=X*0.001
            Y=f[:,1]
            Y_ = Y/150
          
            
            def smooth(y, box_pts):
                box = np.ones(box_pts)/box_pts
                y_smooth = np.convolve(y, box, mode='same')
                return y_smooth
            plt.subplot(3, 3, 4)
            plt.plot(X_,Y_,':ro',label=name,color=next(colors))
            plt.ylabel('# H-bonds',fontsize=14)
            plt.xlabel('Time (ns)',fontsize=14)
            plt.ylim(0, 3.5)
            plt.title('3 water / hg')
            plt.legend(loc='upper right')

            
             
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/HBond/Data/')
with open('data.txt', 'w') as file:
    
    path = '*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('cer2*.xvg')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name,skiprows=25)
       
            X=f[:,0]
            X_=X*0.001
            Y=f[:,1]
            Y_ = Y/150
          
            
            def smooth(y, box_pts):
                box = np.ones(box_pts)/box_pts
                y_smooth = np.convolve(y, box, mode='same')
                return y_smooth
            plt.subplot(3, 3, 5)
            plt.plot(X_,Y_,':ro',label=name,color=next(colors))
            plt.ylabel('# H-bonds',fontsize=14)
            plt.xlabel('Time (ns)',fontsize=14)
            plt.ylim(0, 3.5)
            plt.title('1 water / hg')
            plt.legend(loc='upper right')

            
             
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise
                
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/0.01Wat/HBond/Data/')
with open('data.txt', 'w') as file:
    
    path = '*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('cer2*.xvg')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name,skiprows=25)
       
            X=f[:,0]
            X_=X*0.001
            Y=f[:,1]
            Y_ = Y/150
          
            
            def smooth(y, box_pts):
                box = np.ones(box_pts)/box_pts
                y_smooth = np.convolve(y, box, mode='same')
                return y_smooth
            plt.subplot(3, 3, 6)
            plt.plot(X_,Y_,':ro',label=name,color=next(colors))
            plt.ylabel('# H-bonds',fontsize=14)
            plt.xlabel('Time (ns)',fontsize=14)
            plt.ylim(0, 3.5)
            plt.title('0.01 water / hg')
            plt.legend(loc='upper right')

            
             
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Hbond/Data')
with open('data.txt', 'w') as file:
    
    path = '*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('cer1*.xvg')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name,skiprows=25)
       
            X=f[:,0]
            X_=X*0.001
            Y=f[:,1]
            Y_ = Y/40
          
            
            def smooth(y, box_pts):
                box = np.ones(box_pts)/box_pts
                y_smooth = np.convolve(y, box, mode='same')
                return y_smooth
            plt.subplot(3, 3, 1)
            plt.plot(X_,Y_,':ro',label=name,color=next(colors))
            plt.ylabel('# H-bonds',fontsize=14)
            plt.xlabel('Time (ns)',fontsize=14)
            plt.ylim(0, 3.5)
            plt.title('3 water / hg')
            plt.legend(loc='upper right')

            
             
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/HBond/Data/')
with open('data.txt', 'w') as file:
    
    path = '*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('cer1*.xvg')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name,skiprows=25)
       
            X=f[:,0]
            X_=X*0.001
            Y=f[:,1]
            Y_ = Y/40
          
            
            def smooth(y, box_pts):
                box = np.ones(box_pts)/box_pts
                y_smooth = np.convolve(y, box, mode='same')
                return y_smooth
            plt.subplot(3, 3, 2)
            plt.plot(X_,Y_,':ro',label=name,color=next(colors))
            plt.ylabel('# H-bonds',fontsize=14)
            plt.xlabel('Time (ns)',fontsize=14)
            plt.ylim(0, 3.5)
            plt.title('1 water / hg')
            plt.legend(loc='upper right')

            
             
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise
                
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/0.01Wat/HBond/Data/')
with open('data.txt', 'w') as file:
    
    path = '*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('cer1*.xvg')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name,skiprows=25)
       
            X=f[:,0]
            X_=X*0.001
            Y=f[:,1]
            Y_ = Y/40
          
            
            def smooth(y, box_pts):
                box = np.ones(box_pts)/box_pts
                y_smooth = np.convolve(y, box, mode='same')
                return y_smooth
            plt.subplot(3, 3, 3)
            plt.plot(X_,Y_,':ro',label=name,color=next(colors))
            plt.ylabel('# H-bonds',fontsize=14)
            plt.xlabel('Time (ns)',fontsize=14)
            plt.ylim(0, 3.5)
            plt.title('0.01 water / hg')
            plt.legend(loc='upper right')

            
             
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise

os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Hbond/Data')
with open('data.txt', 'w') as file:
    
    path = '*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('cer3*.xvg')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name,skiprows=25)
       
            X=f[:,0]
            X_=X*0.001
            Y=f[:,1]
            Y_ = Y/50
          
            
            def smooth(y, box_pts):
                box = np.ones(box_pts)/box_pts
                y_smooth = np.convolve(y, box, mode='same')
                return y_smooth
            plt.subplot(3, 3, 7)
            plt.plot(X_,Y_,':ro',label=name,color=next(colors))
            plt.ylabel('# H-bonds',fontsize=14)
            plt.xlabel('Time (ns)',fontsize=14)
            plt.ylim(0, 3.5)
            plt.title('3 water / hg')
            plt.legend(loc='upper right')

            
             
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/1Wat/HBond/Data/')
with open('data.txt', 'w') as file:
    
    path = '*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('cer3*.xvg')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name,skiprows=25)
       
            X=f[:,0]
            X_=X*0.001
            Y=f[:,1]
            Y_ = Y/50
          
            
            def smooth(y, box_pts):
                box = np.ones(box_pts)/box_pts
                y_smooth = np.convolve(y, box, mode='same')
                return y_smooth
            plt.subplot(3, 3, 8)
            plt.plot(X_,Y_,':ro',label=name,color=next(colors))
            plt.ylabel('# H-bonds',fontsize=14)
            plt.xlabel('Time (ns)',fontsize=14)
            plt.ylim(0, 3.5)
            plt.title('1 water / hg')
            plt.legend(loc='upper right')

            
             
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise
                
os.chdir('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/0.01Wat/HBond/Data/')
with open('data.txt', 'w') as file:
    
    path = '*.xvg' 
    path2 = os.getcwd()
    files = glob.glob(path)
    colors = itertools.cycle(["r", "b", "g","y","c","m"])
for name in sorted(glob.glob('cer3*.xvg')):
        try: 
        #with open(name) as f:
            lines = open(name,'r')
            #f = lines.readlines()[18:]
            f = np.loadtxt(name,skiprows=25)
       
            X=f[:,0]
            X_=X*0.001
            Y=f[:,1]
            Y_ = Y/50
          
            
            def smooth(y, box_pts):
                box = np.ones(box_pts)/box_pts
                y_smooth = np.convolve(y, box, mode='same')
                return y_smooth
            plt.subplot(3, 3, 9)
            plt.plot(X_,Y_,':ro',label=name,color=next(colors))
            plt.ylabel('# H-bonds',fontsize=14)
            plt.xlabel('Time (ns)',fontsize=14)
            plt.ylim(0, 3.5)
            plt.title('0.01 water / hg')
            plt.legend(loc='upper right')

            
             
        except IOError as exc: 
            if exc.errno != errno.EISDIR: 
                raise
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/3Wat/Hbond/H_bond.png',dpi=300,bbox_inches='tight',pad_inches=0.00)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import itertools 

plt.figure(figsize=(12,6)) 
colors = itertools.cycle(['blue', 'mediumseagreen','orchid', 'lightblue', 'lightcoral', 'gray'])
 

plt.subplot(1, 3, 3)

bla2 = ['Cer', 'FFA', 'Chol']
Wat1Mean =  np.array([0.38, 0.18, 0.1])
Wat2Mean =  np.array([1.12, 0.48, 0.51])
Wat3Mean =  np.array([0.5, 0.21, 0.14])
Wat4Mean =  np.array([0.04, 0, 0])
Wat5Mean =  np.array([0.75, 0.38, 0.20])
Wat6Mean =  np.array([0.87, 0.16, 0.38])
StdWat1 =   np.array([0.0, 0, 0])
StdWat2 =   np.array([0.2, 0., 0])
StdWat3 =   np.array([0.1, 0, 0])
StdWat4 =   np.array([0.0, 0., 0.])
StdWat5 =   np.array([0.1, 0.0, 0.0])
StdWat6 =   np.array([0.1, 0, 0])
ind = [bla for bla in bla2]   # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, Wat1Mean, width, label='Cer1', yerr=StdWat1,color=next(colors))
p2 = plt.bar(ind, Wat2Mean, width, bottom=Wat1Mean, yerr=StdWat2, color=next(colors))
p3 = plt.bar(ind, Wat3Mean, width, bottom=Wat1Mean+Wat2Mean, yerr=StdWat3, color=next(colors))
p4 = plt.bar(ind, Wat4Mean, width, bottom=Wat1Mean+Wat2Mean+Wat3Mean, yerr=StdWat4, color=next(colors))
p5 = plt.bar(ind, Wat5Mean, width, bottom=Wat1Mean+Wat2Mean+Wat3Mean+Wat4Mean, yerr=StdWat5, color=next(colors))
p6 = plt.bar(ind, Wat6Mean, width, bottom=Wat1Mean+Wat2Mean+Wat3Mean+Wat4Mean+Wat5Mean, yerr=StdWat6, color=next(colors))

plt.ylabel('# H-bonds /hg', fontsize=14)
plt.title('0.01 Wat /hg', fontsize=14)
plt.xticks(ind, ('Cer-X', 'FFA-X', 'Chol-X'), fontsize=14)
plt.yticks(np.arange(0, 8, 1), fontsize=14)
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0], p6[0]), ('Cer1', 'Cer2', 'Cer3', 'Wat', 'Chol', 'FFA'), fontsize=11)



colors = itertools.cycle(['blue', 'mediumseagreen','orchid', 'lightblue', 'lightcoral', 'gray'])

plt.subplot(1, 3, 2)

bla2 = ['Cer', 'FFA', 'Chol']
Wat1Mean =  np.array([0.20, 0.11, 0.05])
Wat2Mean =  np.array([0.54, 0.27, 0.36])
Wat3Mean =  np.array([0.29, 0.13, 0.1])
Wat4Mean =  np.array([2.16, 0.95, 0.98])
Wat5Mean =  np.array([0.51, 0.20, 0.04])
Wat6Mean =  np.array([0.50, 0.04, 0.2])
StdWat1 =   np.array([0.0, 0, 0])
StdWat2 =   np.array([0.2, 0.0, 0])
StdWat3 =   np.array([0.1, 0.0, 0.0])
StdWat4 =   np.array([0.3, 0.1, 0.1])
StdWat5 =   np.array([0.1, 0.0, 0.0])
StdWat6 =   np.array([0.1, 0.0, 0.0])
ind = [bla for bla in bla2]   # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, Wat1Mean, width, label='Cer1', yerr=StdWat1,color=next(colors))
p2 = plt.bar(ind, Wat2Mean, width, bottom=Wat1Mean, yerr=StdWat2, color=next(colors))
p3 = plt.bar(ind, Wat3Mean, width, bottom=Wat1Mean+Wat2Mean, yerr=StdWat3, color=next(colors))
p4 = plt.bar(ind, Wat4Mean, width, bottom=Wat1Mean+Wat2Mean+Wat3Mean, yerr=StdWat4, color=next(colors))
p5 = plt.bar(ind, Wat5Mean, width, bottom=Wat1Mean+Wat2Mean+Wat3Mean+Wat4Mean, yerr=StdWat5, color=next(colors))
p6 = plt.bar(ind, Wat6Mean, width, bottom=Wat1Mean+Wat2Mean+Wat3Mean+Wat4Mean+Wat5Mean, yerr=StdWat6, color=next(colors))

plt.ylabel('# H-bonds /hg', fontsize=14)
plt.title('1 Wat / hg', fontsize=14)
plt.xticks(ind, ('Cer-X', 'FFA-X', 'Chol-X'), fontsize=14)
plt.yticks(np.arange(0, 8, 1), fontsize=14)
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0], p6[0]), ('Cer1', 'Cer2', 'Cer3', 'Wat', 'Chol', 'FFA'), fontsize=11)



colors = itertools.cycle(['blue', 'mediumseagreen','orchid', 'lightblue', 'lightcoral', 'gray'])

plt.subplot(1, 3, 1)

bla2 = ['Cer', 'FFA', 'Chol']
Wat1Mean =  np.array([0.17, 0.08, 0.07])
Wat2Mean =  np.array([0.48, 0.21, 0.21])
Wat3Mean =  np.array([0.21, 0.08, 0.09])
Wat4Mean =  np.array([2.99, 1.37, 1.39])
Wat5Mean =  np.array([0.37, 0.11, 0.08])
Wat6Mean =  np.array([0.37, 0.02, 0.11])
StdWat1 =   np.array([0.0, 0, 0])
StdWat2 =   np.array([0.2, 0.1, 0])
StdWat3 =   np.array([0.1, 0, 0.1])
StdWat4 =   np.array([0.4, 0.1, 0.1])
StdWat5 =   np.array([0.0, 0.0, 0.0])
StdWat6 =   np.array([0.0, 0, 0])


ind = [bla for bla in bla2]   # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, Wat1Mean, width, label='Cer1', yerr=StdWat1,color=next(colors))
p2 = plt.bar(ind, Wat2Mean, width, bottom=Wat1Mean, yerr=StdWat2, color=next(colors))
p3 = plt.bar(ind, Wat3Mean, width, bottom=Wat1Mean+Wat2Mean, yerr=StdWat3, color=next(colors))
p4 = plt.bar(ind, Wat4Mean, width, bottom=Wat1Mean+Wat2Mean+Wat3Mean, yerr=StdWat4, color=next(colors))
p5 = plt.bar(ind, Wat5Mean, width, bottom=Wat1Mean+Wat2Mean+Wat3Mean+Wat4Mean, yerr=StdWat5, color=next(colors))
p6 = plt.bar(ind, Wat6Mean, width, bottom=Wat1Mean+Wat2Mean+Wat3Mean+Wat4Mean+Wat5Mean, yerr=StdWat6, color=next(colors))

plt.ylabel('# H-bonds /hg', fontsize=14)
plt.title('3 Wat / hg', fontsize=14)
plt.xticks(ind, ('Cer-X', 'FFA-X', 'Chol-X'), fontsize=14)
plt.yticks(np.arange(0, 8, 1), fontsize=14)
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0], p6[0]), ('Cer1', 'Cer2', 'Cer3', 'Wat', 'Chol', 'FFA'), fontsize=11)


plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/MODEL/Avg_Hbond_STACKED_2_CerCholFFA.png',dpi=300,bbox_inches='tight',pad_inches=0.55)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import itertools 

plt.figure(figsize=(12,6)) 

#LPP
colors = itertools.cycle(['lightblue', 'blue', 'mediumseagreen','orchid', 'lightcoral', 'gray'])

plt.subplot(1, 3, 2)

bla2 = ['Cer', 'FFA', 'Chol']

Wat1Mean =  np.array([0.17, 0.08, 0.07])
Wat2Mean =  np.array([0.48, 0.21, 0.21])
Wat3Mean =  np.array([0.21, 0.08, 0.09])
Wat4Mean =  np.array([2.99, 1.37, 1.39])
Wat5Mean =  np.array([0.37, 0.11, 0.08])
Wat6Mean =  np.array([0.37, 0.02, 0.11])
StdWat1 =   np.array([0.0, 0, 0])
StdWat2 =   np.array([0.2, 0.1, 0])
StdWat3 =   np.array([0.1, 0, 0.1])
StdWat4 =   np.array([0.4, 0.1, 0.1])
StdWat5 =   np.array([0.0, 0.0, 0.0])
StdWat6 =   np.array([0.0, 0, 0])

ind = [bla for bla in bla2]   # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p4 = plt.bar(ind, Wat4Mean, width, yerr=StdWat4, color=next(colors))
p1 = plt.bar(ind, Wat1Mean, width, bottom=Wat4Mean, label='Cer1', yerr=StdWat1,color=next(colors))
p2 = plt.bar(ind, Wat2Mean, width, bottom=Wat4Mean+Wat1Mean, yerr=StdWat2, color=next(colors))
p3 = plt.bar(ind, Wat3Mean, width, bottom=Wat4Mean+Wat1Mean+Wat2Mean, yerr=StdWat3, color=next(colors))
p5 = plt.bar(ind, Wat5Mean, width, bottom=Wat1Mean+Wat2Mean+Wat3Mean+Wat4Mean, yerr=StdWat5, color=next(colors))
p6 = plt.bar(ind, Wat6Mean, width, bottom=Wat1Mean+Wat2Mean+Wat3Mean+Wat4Mean+Wat5Mean, yerr=StdWat6, color=next(colors))

plt.ylabel('# H-bonds /hg', fontsize=14)
plt.title('LPP', fontsize=14)
plt.minorticks_on()
plt.ylim(0, 6)
plt.xticks(ind, ('Cer-X', 'FFA-X', 'Chol-X'), fontsize=14)
plt.yticks(np.arange(0, 6, 1), fontsize=14)
plt.legend((p4[0], p1[0], p2[0], p3[0], p5[0], p6[0]), ('Wat', 'Cer1', 'Cer2', 'Cer3', 'FFA', 'Chol'), fontsize=11)




colors = itertools.cycle(['lightblue', 'blue', 'mediumseagreen','orchid', 'orange', 'lightcoral', 'gray'])
 
#LPP_l
plt.subplot(1, 3, 1)

bla2 = ['Cer', 'FFA', 'Chol']
Wat1Mean =  np.array([0.13, 0.053, 0.046])           #Cer-Cer1
Wat2Mean =  np.array([0.24, 0.07, 0.063])       #Cer-Cer2
Wat3Mean =  np.array([0.43 , 0.204, 0.192])       #Cer-Cer3
Wat4Mean_ = np.array([0.28, 0.13, 0.1])     #Cer-Cer6
Wat4Mean =  np.array([3.2, 1.35, 1.433])     #Wat, Wat, Wat
Wat5Mean =  np.array([0.45, 0.06, 0.15]) #FFA, FFA, FFA 
Wat6Mean =  np.array([0.40, 0.15, 0.119])  #Chol, Chol, Chol 
StdWat1 =   np.array([0.04, 0.00, 0.0])
StdWat2 =   np.array([0.05, 0.0, 0.0])
StdWat3 =   np.array([0.1, 0.06, 0.1])
StdWat4_ =   np.array([0.1, 0.05, 0.0])
StdWat4 =   np.array([0.1, 0.05, 0.0])
StdWat5 =   np.array([0.2, 0.1, 0.0])
StdWat6 =   np.array([0.2, 0.1, 0.1])

ind = [bla for bla in bla2]   # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p4 = plt.bar(ind, Wat4Mean, width, yerr=StdWat4, color=next(colors))
p1 = plt.bar(ind, Wat1Mean, width, bottom=Wat4Mean, label='Cer1', yerr=StdWat1,color=next(colors))
p2 = plt.bar(ind, Wat2Mean, width, bottom=Wat4Mean+Wat1Mean, yerr=StdWat2, color=next(colors))
p3 = plt.bar(ind, Wat3Mean, width, bottom=Wat4Mean+Wat1Mean+Wat2Mean, yerr=StdWat3, color=next(colors))
p4_ = plt.bar(ind, Wat4Mean_, width, bottom=Wat4Mean+Wat1Mean+Wat2Mean+Wat3Mean, yerr=StdWat4_, color=next(colors))
p5 = plt.bar(ind, Wat5Mean, width, bottom=Wat4Mean+Wat1Mean+Wat2Mean+Wat3Mean+Wat4Mean_, yerr=StdWat5, color=next(colors))
p6 = plt.bar(ind, Wat6Mean, width, bottom=Wat4Mean+Wat1Mean+Wat2Mean+Wat3Mean+Wat4Mean_+Wat5Mean, yerr=StdWat6, color=next(colors))


plt.ylabel('# H-bonds /hg', fontsize=14)
plt.title('LPP$_{L}$', fontsize=14)
plt.minorticks_on()
plt.ylim(0, 6)
plt.xticks(ind, ('Cer-X', 'FFA-X', 'Chol-X'), fontsize=14)
plt.yticks(np.arange(0, 6, 1), fontsize=14)
plt.legend((p4[0], p1[0], p2[0], p3[0], p4_[0], p5[0], p6[0]), ('Wat','Cer1', 'Cer2', 'Cer3', 'Cer6', 'FFA', 'Chol'), fontsize=11)


#LPP + DPG
colors = itertools.cycle(['lightblue', 'blue', 'mediumseagreen','orchid', 'lightcoral', 'gray', 'black'])

plt.subplot(1, 3, 3)

bla2 = ['Cer', 'FFA', 'Chol','DPG']
Wat1Mean =  np.array([0.16, 0.08, 0.05, 0.1])
Wat2Mean =  np.array([0.48, 0.2, 0.21, 0.3])
Wat3Mean =  np.array([0.24, 0.1, 0.1, 0.1])
Wat4Mean =  np.array([2.84, 1.3, 1.4, 3.3])
Wat5Mean =  np.array([0.36, 0.03, 0.11, 0.24])
Wat6Mean =  np.array([0.35, 0.11, 0.05, 0.29])
Wat6Mean_ =  np.array([0.1, 0.03, 0.04, 0.04])

StdWat1 =   np.array([0.1, 0.02, 0.01, 0.1])
StdWat2 =   np.array([0.2, 0.03, 0.03, 0.1])
StdWat3 =   np.array([0.2, 0.01, 0.02, 0.1])
StdWat4 =   np.array([0.5, 0.05, 0.01, 0.2])
StdWat5 =   np.array([0.2, 0.01, 0.01, 0.1])
StdWat6 =   np.array([0.2, 0.02, 0.01, 0.1])
StdWat6_ =   np.array([0.2, 0.01, 0.01, 0.04])
ind = [bla for bla in bla2]   # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p4 = plt.bar(ind, Wat4Mean, width, yerr=StdWat4, color=next(colors))
p1 = plt.bar(ind, Wat1Mean, width, bottom=Wat4Mean, label='Cer1', yerr=StdWat1,color=next(colors))
p2 = plt.bar(ind, Wat2Mean, width, bottom=Wat4Mean+Wat1Mean, yerr=StdWat2, color=next(colors))
p3 = plt.bar(ind, Wat3Mean, width, bottom=Wat4Mean+Wat1Mean+Wat2Mean, yerr=StdWat3, color=next(colors))
p5 = plt.bar(ind, Wat5Mean, width, bottom=Wat1Mean+Wat2Mean+Wat3Mean+Wat4Mean, yerr=StdWat5, color=next(colors))
p6 = plt.bar(ind, Wat6Mean, width, bottom=Wat1Mean+Wat2Mean+Wat3Mean+Wat4Mean+Wat5Mean, yerr=StdWat6, color=next(colors))
p6_ = plt.bar(ind, Wat6Mean_, width, bottom=Wat1Mean+Wat2Mean+Wat3Mean+Wat4Mean+Wat5Mean+Wat6Mean, yerr=StdWat6_, color=next(colors))

plt.ylabel('# H-bonds /hg', fontsize=14)
plt.title('LPP + DPG ', fontsize=14)
plt.xticks(ind, ('Cer-X', 'FFA-X', 'Chol-X', 'DPG-X'), fontsize=14)
plt.minorticks_on()
plt.ylim(0, 6)
plt.yticks(np.arange(0, 6, 1), fontsize=14)
plt.legend((p4[0], p1[0], p2[0], p3[0], p5[0], p6[0], p6_[0]), ('Wat', 'Cer1', 'Cer2', 'Cer3', 'FFA', 'Chol', 'DPG'), fontsize=11, loc = "upper center")


plt.tight_layout()
plt.savefig('/Users/chrisjorg/Documents/Postdoc/Georgetown/Double_bilayer_Sandwich/NEW_DOUBLE_SAND/Analyse_Sandwich/Avg_HBOND_MODEL1-2.png',dpi=300,bbox_inches='tight',pad_inches=0.55)
plt.show()
